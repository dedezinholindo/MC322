// %% [markdown]
// # Laboratório em Estruturas de Programação Java
//
// O laboratório a seguir serve para praticar estruturas de programação Java sem compromisso com a orientação a objetos.

// %% [markdown]
// ## Desafio 1 - Empréstimo
//
// Em um financiamento com juros compostos e número de parcelas fixas parte-se dos seguintes parâmetros:
// * `S` - valor da primeira parcela
// * `N` - número de parcelas
// * `J` - percentual de juros mensal
//
// A primeira parcela a ser paga do financiamento é sempre igual a `S`. A partir daí é feita uma atualização mensal da parcela, em que cada nova parcela é calculada a partir da parcela do mês anterior, conforme a fórmula:
//
// > Parcela<sub>mês</sub> = Parcela<sub>mês-1</sub> * (1 + `J` / 100)
//
// O financiamento encerra quando as `N` parcelas são pagas.
//
// Exemplo:
// * `S`: 200
// * `N`: 5
// * `J`: 1%
//
// Parcelas do financiamento:
// `200`; `202`; `204.02`; `206.06`; `208.12`

// %% [markdown]
// ### Desafio 1 / Parte 1 - Escrevendo o programa sem módulos
//
// Dado o problema descrito, escreva um programa que calcule as parcelas de um empréstimo para os seguintes valores:
// * S: 200
// * N: 5
// * J: 1%
//
// Nesta versão não use outro módulo além da função principal.

// %%
public class Main{
     static void main(){
        double s = 200;
        int n = 5;
        double j = 1;
        for (int i = 0; i < n; i++){
            System.out.printf("%.2f ", s);
            s *= (1 + j/100);
        }
    }
}
// Out:
// com.twosigma.beaker.javash.bkr9d9c8345.Main

// %%
Main.main();
// Out:
// 200.00 202.00 204.02 206.06 208.12
// null

// %% [markdown]
// ### Desafio 1 / Parte 2 - Escrevendo módulos
//
// Reescreva o código acima de forma que seu programa faça uso de uma função que seja responsável pelo cálculo de uma parcela X do empréstimo. Podem ser usadas mais funções (métodos) conforme a necessidade.

// %%
public class Funcoes {
    static void parcela (double valor, int num_parcela, double j){
        for (int i = 0; i < num_parcela - 1; i++){
            valor *= (1 + j/100);
        }
        System.out.printf("%.2f ", valor);
    }
}
// Out:
// com.twosigma.beaker.javash.bkr9d9c8345.Funcoes

// %%
public class Main {
    static void main (){
        double s = 200;
        int n = 5;
        double j = 1;
        for (int i = 1; i <= n; i++){
            Funcoes.parcela(s, i, j);
        }
    }
}
// Out:
// com.twosigma.beaker.javash.bkr9d9c8345.Main

// %%
Main.main();
// Out:
// 200.00 202.00 204.02 206.06 208.12
// null

// %% [markdown]
// ## Desafio 2
//
// Escreva um programa que sorteie um número inteiro entre `0` e `9999` o número deve ser mostrado, em seguida convertido para binário e a versão binária deve ser apresentada no console. A conversão decimal/binário deve ser computada por um programa feito por você.

// %%
import java.util.Random;

public class Funcoes {
    static int gerar_numero(int max){
        Random rand = new Random();
        return rand.nextInt(max);
    }
    
    static void mostrar_inverso_palavra(StringBuilder palavra){
        for (int i = palavra.length() - 1; i >= 0; i--){
            System.out.print(palavra.charAt(i));
        }
    }
    
    static void transformar_em_binario(int numero){
        StringBuilder num_binario = new StringBuilder();
        while (numero > 0){
            int bit = numero % 2;
            num_binario.append(bit);
            numero /= 2;
        }
        mostrar_inverso_palavra(num_binario);
    }
}
// Out:
// com.twosigma.beaker.javash.bkr9d9c8345.Funcoes

// %%
public class Main{
    static void main(){
        int max = 9999;
        int num = Funcoes.gerar_numero(max + 1);
        System.out.print("O número " + num + " em binário é ");
        Funcoes.transformar_em_binario(num);
    }
}
// Out:
// com.twosigma.beaker.javash.bkr9d9c8345.Main

// %%
Main.main();
// Out:
// O número 1821 em binário é 11100011101
// null

// %% [markdown]
// ## Desafio 3
//
// Uma molécula de DNA pode ser definida a partir de uma cadeia que representa a sequência de suas bases:
// A - Adenina
// C - Citisina
// G - Guanina
// T - Tinina
//
// Desse modo, uma string pode ser usada para representar um segmento do DNA da seguinte maneira: `ATTACGCGCAAAC`.
//
// Escreva uma função (método) que codifique a cadeia de RNA produzida a partir de uma cadeia de DNA. A função deve ser genérica o suficiente para ser aplicável a qualquer cadeia. A entrada é uma string (DNA) e o retorno é uma string (RNA).
//
// Escreva um programa que teste esta função com uma cadeia de DNA de sua escolha.

// %%
public class Funcoes {
    static char comparacao(char letra){
        switch (letra){
            case 'T':
                return 'A';
            case 'G':
                return 'C';
            case 'C':
                return 'G';
            case 'A':
                return 'U';
            default:
                return ' ';
        }
    }
    
    static void escrever_rna(char rna[]){
        for (int i = 0; i < rna.length; i++){
            System.out.print(rna[i]);
        }
    }
    
    static void transformar_dna(String dna){
        char rna[];
        rna = new char[dna.length()];
        for (int i = 0; i < dna.length(); i++){
            rna[i] = comparacao(dna.charAt(i));
        }
        escrever_rna(rna);
    }
}
// Out:
// com.twosigma.beaker.javash.bkr9d9c8345.Funcoes

// %%
public class Main
{
    static void main(){
        String dna = "ATTACGCGCAAAC";
        Funcoes.transformar_dna(dna);
    }
}
// Out:
// com.twosigma.beaker.javash.bkr9d9c8345.Main

// %%
Main.main();
// Out:
// UAAUGCGCGUUUG
// null

// %% [markdown]
// ## Desafio 4
//
// Uma empresa precisa realizar uma estatística do salário de seus funcionários.
//
// Para fins de teste, os salários devem ser gerados aleatoriamente com valores variando entre R\\$ 2.500 e R\\$ 15.000.
//
// Escreva um programa que gere uma lista contendo os salários de 50 funcionários da empresa e mostre no console quantos funcionários ganham salário acima da média.

// %%
import java.util.Random;

public class Funcoes {
    static double gerar_salario(double max, double min){
        Random rand = new Random();
        double sal = 0;
        do{
            sal = (rand.nextDouble() * max);
        } while(sal < min);
        return sal;
    }
    
    static double[] criar_salarios(int n, double max, double min){
        double salarios[] = new double[n];
        for (int i = 0; i < n; i++){
            salarios[i] = gerar_salario(max, min);
        }
        return salarios;
    }
    
    static double calcular_media(double salarios[]){
        double media = 0;
        for (int i = 0; i < salarios.length; i++){
            media += salarios[i];
        }
        media = media/salarios.length;
        return media;
    }
    
    static int acima_da_media(double media, double salarios[]){
        int contador = 0;
        for (int i = 0; i < salarios.length; i++){
            if (salarios[i] > media)
                contador += 1;
        }
        return contador;
    }       
}
// Out:
// com.twosigma.beaker.javash.bkr9d9c8345.Funcoes

// %%
public class Main {
    static void main(){
        int n = 50;
        double max = 15000;
        double min = 2500;
        double salarios[] = Funcoes.criar_salarios(n, max, min);
        double media = Funcoes.calcular_media(salarios);
        int acima = Funcoes.acima_da_media(media, salarios);
        System.out.println("Há " + acima + " funcionários com salário acima da média.");
    }
}
// Out:
// com.twosigma.beaker.javash.bkr9d9c8345.Main

// %%
Main.main();
// Out:
// Há 22 funcionários com salário acima da média.
// null
